# %% [markdown]
# <a href="https://colab.research.google.com/github/chaitanyaksingh2005/DSA/blob/main/univariate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 343          344         0       2
# 516          517         1       2
# 718          719         0       3
# 259          260         1       2
# 148          149         0       2
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 343  Sedgwick, Mr. Charles Frederick Waddington    male  25.0      0      0
# 516                Lemore, Mrs. (Amelia Milley)  female  34.0      0      0
# 718                         McEvoy, Mr. Michael    male   NaN      0      0
# 259                 Parrish, Mrs. (Lutie Davis)  female  50.0      0      1
# 148    Navratil, Mr. Michel ("Louis M Hoffman")    male  36.5      0      2
#
#          Ticket  Fare Cabin Embarked
# 343      244361  13.0   NaN        S
# 516  C.A. 34260  10.5   F33        S
# 718       36568  15.5   NaN        Q
# 259      230433  26.0   NaN        S
# 148      230080  26.0    F2        S

# %%
sns.countplot(x=df['Pclass'])
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(x=df['Sex'])
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.boxplot(x=df['Sex'])
# Out:
# <Axes: xlabel='Sex'>

# %%
df['Survived'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['Survived'].value_counts().plot(kind='box')
# Out:
# <Axes: >

# %%
# Out:
# <bound method IndexOpsMixin.value_counts of 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64>

# %%
sns.histplot(df['Age'],bins=4)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.distplot(df['Age'],kde=True)
# Out:
# /tmp/ipykernel_2913/755051826.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'],kde=True)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
              sns.boxplot(x=df['Fare'])
# Out:
# <Axes: xlabel='Fare'>

# %%
df['Age'].min()*10
# Out:
# 4.2

# %%
x=df['Ticket'].value_counts().head(10).plot(kind='pie')

# %%
df['Age'].mean()
# Out:
# np.float64(29.69911764705882)

# %%
df['Age'].skew()
# Out:
# np.float64(0.38910778230082704)
